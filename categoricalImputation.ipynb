# %% [markdown]
# <a href="https://colab.research.google.com/github/abdul12013/LERN/blob/main/categoricalImputation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data=pd.read_csv(r"/content/1_1_2023_general.csv")
data.head()
# Out:
#    connect_price            created_on               tz_date  \
# 0              6  2023-01-01T17:33:29Z  2023-01-01T17:33:29Z
# 1              2  2023-01-01T17:38:19Z  2023-01-01T17:38:19Z
# 2              4  2023-01-01T17:38:17Z  2023-01-01T17:38:17Z
# 3              2  2023-01-01T17:38:03Z  2023-01-01T17:38:03Z
# 4              4  2023-01-01T17:37:54Z  2023-01-01T17:37:54Z
#
#              duration    engagement  freelancers_to_hire  amount_amount  \
# 0  More than 6 months  30+ hrs/week                    1            NaN
# 1   Less than 1 month           NaN                    1           30.0
# 2   Less than 1 month           NaN                    1          100.0
# 3       3 to 6 months           NaN                    1          500.0
# 4       1 to 3 months           NaN                    5          350.0
#
#    hourly_rate          type         job_ts  ... total_freelancers_to_hire  \
# 0         30.0        hourly  1672594409972  ...                         1
# ...

# %%
data.isnull().sum()
# Out:
# connect_price                            0
# created_on                               0
# tz_date                                  0
# duration                                 0
# engagement                            2191
# freelancers_to_hire                      0
# amount_amount                         2804
# hourly_rate                           3205
# type                                     0
# job_ts                                   0
# proposals_tier                           0
# published_on                             0
# renewed_on                            4915
# tier                                     0
# title                                    0
# total_freelancers_to_hire                0
# uid                                      0
# client_company_org_uid                   0
# client_payment_verification_status     113
# client_total_feedback                    0
# client_total_reviews                     0
# client_total_spent                       0
# ...

# %%
data.ffill(inplace=True)

# %%
data.head()
# Out:
#    connect_price            created_on               tz_date  \
# 0              6  2023-01-01T17:33:29Z  2023-01-01T17:33:29Z
# 1              2  2023-01-01T17:38:19Z  2023-01-01T17:38:19Z
# 2              4  2023-01-01T17:38:17Z  2023-01-01T17:38:17Z
# 3              2  2023-01-01T17:38:03Z  2023-01-01T17:38:03Z
# 4              4  2023-01-01T17:37:54Z  2023-01-01T17:37:54Z
#
#              duration    engagement  freelancers_to_hire  amount_amount  \
# 0  More than 6 months  30+ hrs/week                    1            NaN
# 1   Less than 1 month  30+ hrs/week                    1           30.0
# 2   Less than 1 month  30+ hrs/week                    1          100.0
# 3       3 to 6 months  30+ hrs/week                    1          500.0
# 4       1 to 3 months  30+ hrs/week                    5          350.0
#
#    hourly_rate          type         job_ts  ... total_freelancers_to_hire  \
# 0         30.0        hourly  1672594409972  ...                         1
# ...

# %% [markdown]
# Back filling string imputation method

# %%
data2=pd.read_csv(r"/content/1_1_2023_general.csv")
data2.head(10)
# Out:
#    connect_price            created_on               tz_date  \
# 0              6  2023-01-01T17:33:29Z  2023-01-01T17:33:29Z
# 1              2  2023-01-01T17:38:19Z  2023-01-01T17:38:19Z
# 2              4  2023-01-01T17:38:17Z  2023-01-01T17:38:17Z
# 3              2  2023-01-01T17:38:03Z  2023-01-01T17:38:03Z
# 4              4  2023-01-01T17:37:54Z  2023-01-01T17:37:54Z
# 5              6  2023-01-01T17:37:37Z  2023-01-01T17:37:37Z
# 6              2  2023-01-01T17:37:20Z  2023-01-01T17:37:20Z
# 7              1  2023-01-01T17:36:36Z  2023-01-01T17:36:36Z
# 8              6  2023-01-01T17:36:33Z  2023-01-01T17:36:33Z
# 9              4  2023-01-01T17:35:56Z  2023-01-01T17:35:56Z
#
#              duration             engagement  freelancers_to_hire  \
# 0  More than 6 months           30+ hrs/week                    1
# 1   Less than 1 month                    NaN                    1
# 2   Less than 1 month                    NaN                    1
# ...

# %%
data2.isnull().sum()/data.shape[0]*100
# Out:
# connect_price                          0.000000
# created_on                             0.000000
# tz_date                                0.000000
# duration                               0.000000
# engagement                            43.863864
# freelancers_to_hire                    0.000000
# amount_amount                         56.136136
# hourly_rate                           64.164164
# type                                   0.000000
# job_ts                                 0.000000
# proposals_tier                         0.000000
# published_on                           0.000000
# renewed_on                            98.398398
# tier                                   0.000000
# title                                  0.000000
# total_freelancers_to_hire              0.000000
# uid                                    0.000000
# client_company_org_uid                 0.000000
# client_payment_verification_status     2.262262
# client_total_feedback                  0.000000
# ...

# %%
data2.bfill(inplace=True)

# %%
data2.isnull().sum()/data.shape[0]*100
# Out:
# connect_price                         0.000000
# created_on                            0.000000
# tz_date                               0.000000
# duration                              0.000000
# engagement                            0.000000
# freelancers_to_hire                   0.000000
# amount_amount                         0.080080
# hourly_rate                           0.000000
# type                                  0.000000
# job_ts                                0.000000
# proposals_tier                        0.000000
# published_on                          0.000000
# renewed_on                            1.701702
# tier                                  0.000000
# title                                 0.000000
# total_freelancers_to_hire             0.000000
# uid                                   0.000000
# client_company_org_uid                0.000000
# client_payment_verification_status    0.000000
# client_total_feedback                 0.000000
# ...

# %% [markdown]
# categorical imputation using mod

# %% [markdown]
# mode kaise nikalste hai :
#     data['renewed_on'].mode()

# %%
data['renewed_on'].mode()[0]
# Out:
# '2023-01-01T12:27:48Z'

# %%
data['renewed_on'].fillna(data['renewed_on'].mode()[0],inplace=True)

# %%
data.head(10)
# Out:
#    connect_price            created_on               tz_date  \
# 0              6  2023-01-01T17:33:29Z  2023-01-01T17:33:29Z
# 1              2  2023-01-01T17:38:19Z  2023-01-01T17:38:19Z
# 2              4  2023-01-01T17:38:17Z  2023-01-01T17:38:17Z
# 3              2  2023-01-01T17:38:03Z  2023-01-01T17:38:03Z
# 4              4  2023-01-01T17:37:54Z  2023-01-01T17:37:54Z
# 5              6  2023-01-01T17:37:37Z  2023-01-01T17:37:37Z
# 6              2  2023-01-01T17:37:20Z  2023-01-01T17:37:20Z
# 7              1  2023-01-01T17:36:36Z  2023-01-01T17:36:36Z
# 8              6  2023-01-01T17:36:33Z  2023-01-01T17:36:33Z
# 9              4  2023-01-01T17:35:56Z  2023-01-01T17:35:56Z
#
#              duration             engagement  freelancers_to_hire  \
# 0  More than 6 months           30+ hrs/week                    1
# 1   Less than 1 month  Less than 30 hrs/week                    1
# 2   Less than 1 month  Less than 30 hrs/week                    1
# ...

# %%
data.isnull().sum()
# Out:
# connect_price                         0
# created_on                            0
# tz_date                               0
# duration                              0
# engagement                            0
# freelancers_to_hire                   0
# amount_amount                         4
# hourly_rate                           0
# type                                  0
# job_ts                                0
# proposals_tier                        0
# published_on                          0
# renewed_on                            0
# tier                                  0
# title                                 0
# total_freelancers_to_hire             0
# uid                                   0
# client_company_org_uid                0
# client_payment_verification_status    0
# client_total_feedback                 0
# client_total_reviews                  0
# client_total_spent                    0
# client_location_country               0
# ...

# %% [markdown]
# filling mode to every object type data

# %%
data3=pd.read_csv(r"/content/1_1_2023_general.csv")
for i in data3.select_dtypes(include="object").columns[data3.select_dtypes(include="object").isnull().sum() > 0]:
  print(i)
  data3[i].fillna(data3[i].mode()[0],inplace=True)
# Out:
# engagement
# renewed_on
# <ipython-input-38-4d08539d4148>:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data3[i].fillna(data3[i].mode()[0],inplace=True)

# %%
data3.isnull().sum()
# Out:
# connect_price                            0
# created_on                               0
# tz_date                                  0
# duration                                 0
# engagement                               0
# freelancers_to_hire                      0
# amount_amount                         2804
# hourly_rate                           3205
# type                                     0
# job_ts                                   0
# proposals_tier                           0
# published_on                             0
# renewed_on                               0
# tier                                     0
# title                                    0
# total_freelancers_to_hire                0
# uid                                      0
# client_company_org_uid                   0
# client_payment_verification_status     113
# client_total_feedback                    0
# client_total_reviews                     0
# client_total_spent                       0
# ...
